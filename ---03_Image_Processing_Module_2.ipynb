# %% [markdown]
# Python OpenCV2 by Vitthal![image.png](attachment:image.png)

# %% [markdown]
# ## Image Processing Module 2

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Filters

# %% [markdown]
# #### About Convolution

# %%
img = cv.imread('pylogo.png')

kernel = np.ones((6,6),np.float32)/36
dst = cv.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# #### Different types of filters like Averaging blur

# %% [markdown]
# ##### Blurring

# %%
img = cv.imread('lena.png')

blur = cv.blur(img,(5,5))

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ##### Gaussian

# %%
img = cv.imread('pylogo.png')

blur = cv.GaussianBlur(img,(15,15),4)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ##### Median

# %%
img = cv.imread('pylogo.png')

blur = cv.medianBlur(img,9)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Thresholding

# %% [markdown]
# #### Basic Thresholding

# %%
img = cv.imread('gradient.jpg',0)
ret,thresh1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
ret,thresh2 = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)
ret,thresh3 = cv.threshold(img,127,255,cv.THRESH_TRUNC)
ret,thresh4 = cv.threshold(img,127,255,cv.THRESH_TOZERO)
ret,thresh5 = cv.threshold(img,127,255,cv.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

plt.figure(figsize=(10,4))
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %% [markdown]
# #### Adaptive Thresholding

# %%
# TBD: Somehow adaptiveThreshold function is broken
img = cv.imread('book.jpg',0)
ret,th1 = cv.threshold(img,100,205,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img,205,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY,15,5)
th3 = cv.adaptiveThreshold(img,205,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY,15,5)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

plt.figure(figsize=(20,8))
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
# TBD: Somehow adaptiveThreshold function is broken
img = cv.imread('sudoku.jpg',0)
ret,th1 = cv.threshold(img,100,205,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img,205,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY,15,5)
th3 = cv.adaptiveThreshold(img,205,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY,15,5)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

plt.figure(figsize=(20,8))
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# ## Edge Detection

# %%
img = cv.imread('lena.png',0)
ROI = img[75:160,100:160] # ROI : Region Of Interest
edges = cv.Canny(ROI,100,250)
img[75:160,100:160] = edges
plt.figure(figsize=(16,4))
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
# plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()
